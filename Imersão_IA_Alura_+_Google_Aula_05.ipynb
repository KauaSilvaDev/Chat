# %% [markdown]
# <a href="https://colab.research.google.com/github/KauaSilvaDev/Chat/blob/main/Imers%C3%A3o_IA_Alura_%2B_Google_Aula_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U -q google-generativeai

# %%
#Importações e configurações iniciais
import numpy as np
import pandas as pd
import google.generativeai as genai

GOOGLE_API_KEY="AIzaSyA7CYrTtyMzBctjh-XXNdRLFXCERHNhBDc"
genai.configure(api_key=GOOGLE_API_KEY)

# %%
for m in genai.list_models():
  if 'embedContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/embedding-001
# models/text-embedding-004

# %%
#Exemplo de embedding
title = "A próxima geração de IA para desenvolvedores e Google Workspace"

sample_text = (
    "(Título: A próxima geração de IA para desenvolvedores e Google Workspace"
    "\n\n"
    "Artigo completo:\n\n"
    "\n\n"
    "Gemini API & Google AI Studio: Uma maneira acessível de explorar e criar protótipos com aplicações de IA generativa)"
)

embeddings = genai.embed_content(model="models/embedding-001",
                                 content=sample_text,
                                 title=title,
                                 task_type="RETRIEVAL_DOCUMENT")
print(embeddings)
# Out:
# {'embedding': [0.047816083, -0.034096025, -0.020862741, 0.018576818, 0.066987686, -0.009625223, -0.031235918, -0.018908933, 0.06614052, 0.064080305, 0.005932952, 0.012422165, -0.04533464, -0.023210384, 0.007748805, -0.028438767, 0.021932872, -0.009891885, -0.03203065, -0.0026567029, 0.007659595, 0.004285269, -0.030272301, -0.06663913, -0.017087916, 0.020815397, 0.013908606, -0.03681149, -0.03319799, 0.028327024, -0.051180296, 0.05574093, -0.035669517, 0.008317563, -0.037112743, -0.041306473, -0.02374717, -0.04512836, -0.0009921885, -0.003021653, 0.007278183, -0.08723361, -0.007927687, 0.030119585, -0.0082076, -0.019161047, 0.049159624, 0.04268145, 0.01589264, -0.060126588, 0.028266761, 0.02530915, 0.061999474, -0.044829674, -0.008065188, -0.0045695375, 0.025058163, -0.039742112, 0.028406218, 0.0011437949, -0.003589333, 0.021451348, -0.021164559, 0.052193217, 0.021031424, -0.055440765, -0.038436797, 0.0014860897, 0.010297341, 0.05087032, 0.009086422, 0.015473319, 0.061146874, -0.06348
# ...

# %%
#Listagem de documentos que serão buscados
DOCUMENT1 = {
    "Título": "Operação do sistema de controle climático",
    "Conteúdo": "O Googlecar tem um sistema de controle climático que permite ajustar a temperatura e o fluxo de ar no carro. Para operar o sistema, use os controles no painel ou comandos de voz.",
}
DOCUMENT2 = {
    "Título": "Touchscreen",
    "Conteúdo": "O seu Googlecar tem uma grande tela sensível ao toque que fornece acesso a uma variedade de recursos, incluindo navegação, entretenimento e configurações do veículo.",
}
DOCUMENT3 = {
    "Título": "Mudança de marchas",
    "Conteúdo": "Seu Googlecar tem uma transmissão automática. Para trocar as marchas, basta mover a alavanca de câmbio para a posição desejada.",
}

documents = [DOCUMENT1, DOCUMENT2, DOCUMENT3]

# %%
df = pd.DataFrame(documents)
df.columns = ["Titulo", "Conteudo"]
df
# Out:
#                                       Titulo  \
# 0  Operação do sistema de controle climático
# 1                                Touchscreen
# 2                         Mudança de marchas
#
#                                             Conteudo
# 0  O Googlecar tem um sistema de controle climáti...
# 1  O seu Googlecar tem uma grande tela sensível a...
# 2  Seu Googlecar tem uma transmissão automática. ...

# %%
model = "model/embeddings-001"

# %%
def embed_fn(title, text):
  return genai.embed_content(model="models/embedding-001",
                                 content=sample_text,
                                 title=title,
                                 task_type="RETRIEVAL_DOCUMENT")["embedding"]

# %%
df["Embeddings"] = df.apply(lambda row: embed_fn(row["Titulo"], row["Conteudo"]), axis=1)
df
# Out:
#                                       Titulo  \
# 0  Operação do sistema de controle climático
# 1                                Touchscreen
# 2                         Mudança de marchas
#
#                                             Conteudo  \
# 0  O Googlecar tem um sistema de controle climáti...
# 1  O seu Googlecar tem uma grande tela sensível a...
# 2  Seu Googlecar tem uma transmissão automática. ...
#
#                                           Embeddings
# 0  [0.028850375, -0.030833425, -0.04395809, 0.048...
# 1  [0.0499776, -0.054239534, -0.02713017, -0.0049...
# 2  [0.050644685, -0.02305418, -0.014955408, 0.025...

# %%
def gerar_e_buscar_consulta(consulta, base, model):
  embedding_da_consulta = genai.embed_content(model=model,
                                 content=consulta,
                                 title=title,
                                 task_type="RETRIEVAL_QUERY")["embedding"]

  produtos_escalares = np.dot(np.stack(df["Embeddings"]), embedding_da_consulta)

  indice = np.argmax(produtos_escalares)
  return df.iloc[indice]["Conteudo"]

# %%
consulta = "Como se troca a marcha de um carro do Goolgle?"

trecho = gerar_e_buscar_consulta(consulta, df, model)
print(trecho)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-8429779f5fd3> in <cell line: 3>()
#       1 consulta = "Como se troca a marcha de um carro do Goolgle?"
#       2
# ----> 3 trecho = gerar_e_buscar_consulta(consulta, df, models)
#       4 print(trecho)
#
# NameError: name 'models' is not defined
